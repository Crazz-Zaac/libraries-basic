# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Understanding 'chicago.csv' data

# %%
df = pd.read_csv("chicago.csv")
df.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year
# 0  Subscriber    Male      1991.0
# 1    Customer     NaN         NaN
# 2  Subscriber  Female      1982.0
# 3  Subscriber    Male      1966.0
# ...

# %%
df.columns
# Out:
# Index(['Start Time', 'End Time', 'Trip Duration', 'Start Station',
#        'End Station', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Trip Duration   Birth Year
# count     400.000000   330.000000
# mean      938.215000  1980.533333
# std      2466.972184    11.723011
# min        97.000000  1949.000000
# 25%       407.000000  1973.000000
# 50%       634.000000  1984.000000
# 75%       997.750000  1989.000000
# max     47551.000000  1999.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Start Time     400 non-null    object
#  1   End Time       400 non-null    object
#  2   Trip Duration  400 non-null    int64
#  3   Start Station  400 non-null    object
#  4   End Station    400 non-null    object
#  5   User Type      400 non-null    object
#  6   Gender         330 non-null    object
#  7   Birth Year     330 non-null    float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 25.1+ KB

# %%
df.isnull()
# Out:
#      Start Time  End Time  Trip Duration  Start Station  End Station  \
# 0         False     False          False          False        False
# 1         False     False          False          False        False
# 2         False     False          False          False        False
# 3         False     False          False          False        False
# 4         False     False          False          False        False
# ..          ...       ...            ...            ...          ...
# 395       False     False          False          False        False
# 396       False     False          False          False        False
# 397       False     False          False          False        False
# 398       False     False          False          False        False
# 399       False     False          False          False        False
#
#      User Type  Gender  Birth Year
# 0        False   False       False
# 1        False    True        True
# ...

# %%
df['End Station']
# Out:
# 0                     Federal St & Polk St
# 1      Orleans St & Merchandise Mart Plaza
# 2                  Paulina Ave & North Ave
# 3           California Ave & Milwaukee Ave
# 4             Financial Pl & Congress Pkwy
#                       ...
# 395               Racine Ave & Randolph St
# 396           Clinton St & Washington Blvd
# 397                 Michigan Ave & Lake St
# 398                     Daley Center Plaza
# 399      Sangamon St & Washington Blvd (*)
# Name: End Station, Length: 400, dtype: object

# %%
unique_station = df['End Station']
unique_station.unique()
# Out:
# array(['Federal St & Polk St', 'Orleans St & Merchandise Mart Plaza',
#        'Paulina Ave & North Ave', 'California Ave & Milwaukee Ave',
#        'Financial Pl & Congress Pkwy', 'Franklin St & Monroe St',
#        'Morgan St & Lake St', 'Michigan Ave & Lake St',
#        'Franklin St & Jackson Blvd', 'Clark St & Lake St',
#        'Stetson Ave & South Water St', 'Rush St & Hubbard St',
#        'Clark St & Elm St', 'Damen Ave & Division St',
#        'Sangamon St & Washington Blvd (*)', 'Halsted St & Roscoe St',
#        'Clinton St & Washington Blvd', 'Lincoln Ave & Roscoe St',
#        'Central St & Girard Ave', 'Wells St & Elm St',
#        'Clinton St & Madison St', 'Green St & Randolph St',
#        'Troy St & North Ave', 'Wabash Ave & Roosevelt Rd',
#        'State St & Randolph St', 'Daley Center Plaza',
#        'Clinton St & Jackson Blvd', 'Stave St & Armitage Ave',
#        'Halsted St & Wrightwood Ave', 'Talman Ave & Addison St',
# ...

# %%
df.dtypes
# Out:
# Start Time        object
# End Time          object
# Trip Duration      int64
# Start Station     object
# End Station       object
# User Type         object
# Gender            object
# Birth Year       float64
# dtype: object

# %% [markdown]
# ## Practice Problem
# ### 1: Compute the Most Popular Start Hour

# %%
df = pd.read_csv('chicago.csv')
df.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year
# 0  Subscriber    Male      1991.0
# 1    Customer     NaN         NaN
# 2  Subscriber  Female      1982.0
# 3  Subscriber    Male      1966.0
# ...

# %%
df['Start Time'] = pd.to_datetime(chicago['Start Time'])
df.head()
# Out:
#            Start Time             End Time  Trip Duration  \
# 0 2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1 2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2 2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3 2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4 2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year
# 0  Subscriber    Male      1991.0
# 1    Customer     NaN         NaN
# 2  Subscriber  Female      1982.0
# 3  Subscriber    Male      1966.0
# ...

# %%
# extract hour from the Start Time column to create an hour column
df['hour'] = df['Start Time'].dt.hour
df.head()
# Out:
#            Start Time             End Time  Trip Duration  \
# 0 2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1 2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2 2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3 2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4 2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year  hour
# 0  Subscriber    Male      1991.0    18
# 1    Customer     NaN         NaN    19
# 2  Subscriber  Female      1982.0    17
# ...

# %%
df['Start Time'].dt.week
# Out:
# 0      22
# 1      24
# 2       7
# 3      17
# 4       4
#        ..
# 395     6
# 396    21
# 397    23
# 398    20
# 399    20
# Name: Start Time, Length: 400, dtype: int64

# %%
# find the most common hour (from 0 to 23)
popular_hour = df['hour'].mode()[0]
print('Most Popular Start Hour:', popular_hour)
# Out:
# Most Popular Start Hour: 17

# %% [markdown]
# ## Practice Problem
# ### 2: Display a Breakdown of User Types
# There are different types of users specified in the "User Type" column. Find how many there are of each type and store the counts in a pandas Series in the user_types variable.
#
# Hint: What pandas function returns a Series with the counts of each unique value in a column?

# %%
df.head()
# Out:
#            Start Time             End Time  Trip Duration  \
# 0 2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1 2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2 2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3 2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4 2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year  hour
# 0  Subscriber    Male      1991.0    18
# 1    Customer     NaN         NaN    19
# 2  Subscriber  Female      1982.0    17
# ...

# %%
# print value counts for each user type
user_types = df['User Type'].value_counts()
user_types
# Out:
# Subscriber    330
# Customer       70
# Name: User Type, dtype: int64

# %% [markdown]
# ## Practice Problem
# ### 3: Load and Filter the Dataset
# This is a bit of a bigger task, which involves choosing a dataset to load and filtering it based on a specified month and day. In the quiz below, you'll implement the load_data() function, which you can use directly in your project. There are four steps:
#
# 1. **Load the dataset for the specified city.** Index the global CITY_DATA dictionary object to get the corresponding filename for the given city name.
# 2. **Create month and day_of_week columns.** Convert the "Start Time" column to datetime and extract the month number and weekday name into separate columns using the datetime module.
# 3. **Filter by month.** Since the month parameter is given as the name of the month, you'll need to first convert this to the corresponding month number. Then, select rows of the dataframe that have the specified month and reassign this as the new dataframe.
# 4. **Filter by day of week.** Select rows of the dataframe that have the specified day of week and reassign this as the new dataframe. (Note: Capitalize the day parameter with the title() method to match the title case used in the day_of_week column!)

# %%
CITY_DATA = {'chicago': 'chicago.csv',
            'new york city': 'new_york_city.csv',
            'washington': 'washington.csv'}

def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month 
    and day if applicable.
    """
    
    # loading the file into a dataframe
    df = pd.read_csv(CITY_DATA[city])
    
    # converting the Start Time column into datetime
    df['Start Time'] = pd.to_datetime(df['Start Time'])
    
    # extracting month and day of week from Start Time to create new columns
    df['month'] = df['Start Time'].dt.month
    df['day_of_week'] = df['Start Time'].dt.day_name()
    # df['day_of_week'] = df['Start Time'].dt.weekday_name
    
    #filter by month if applicable
    if month != 'all':
        #use the index of the months list to get the corresponding int 
        months = ['january', 'february', 'march', 'april', 'may', 'june']
        month = months.index(month) + 1
        
        #filter by month to create the new dataframe
        df = df[df['month'] == month]
    
    if day != 'all':
        #filter by day of week to create the new dataframe
        df = df[df['day_of_week'] == day.title()]
    
    return df

# %%
df = load_data('chicago', 'march', 'friday')
df
# Out:
#              Start Time             End Time  Trip Duration  \
# 40  2017-03-24 13:06:37  2017-03-24 13:10:44            247
# 59  2017-03-03 07:55:48  2017-03-03 07:57:41            113
# 68  2017-03-17 12:14:50  2017-03-17 12:22:38            468
# 75  2017-03-10 13:40:54  2017-03-10 13:45:09            255
# 83  2017-03-24 14:15:43  2017-03-24 14:27:04            681
# 126 2017-03-24 12:39:19  2017-03-24 12:52:11            772
# 224 2017-03-31 19:11:12  2017-03-31 19:18:53            461
# 247 2017-03-10 08:21:05  2017-03-10 08:23:28            143
# 290 2017-03-24 10:55:53  2017-03-24 11:01:27            334
# 343 2017-03-17 17:51:31  2017-03-17 18:00:16            525
# 348 2017-03-31 07:47:14  2017-03-31 07:55:38            504
#
#                    Start Station                End Station   User Type  \
# 40         Broadway & Berwyn Ave      Clark St & Berwyn Ave  Subscriber
# 59        Clark St & Chicago Ave        Wells St & Huron St  Subscriber
# ...

# %% [markdown]
# ## Exploring and visualizing data

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('chicago.csv')
df.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year
# 0  Subscriber    Male      1991.0
# 1    Customer     NaN         NaN
# 2  Subscriber  Female      1982.0
# 3  Subscriber    Male      1966.0
# ...

# %%
df['Trip Duration'].max()
# Out:
# 47551

# %%
genders = df['Gender'].value_counts()
genders
# Out:
# Male      244
# Female     86
# Name: Gender, dtype: int64

# %%
# only male users
male_users = df[df['Gender'] == 'Male']
male_users.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 6  2017-04-24 08:33:31  2017-04-24 08:38:47            316
# 7  2017-03-21 07:23:58  2017-03-21 07:33:17            559
# 9  2017-04-06 09:15:52  2017-04-06 09:22:11            379
#
#                   Start Station                     End Station   User Type  \
# 0     Columbus Dr & Randolph St            Federal St & Polk St  Subscriber
# 3  Spaulding Ave & Armitage Ave  California Ave & Milwaukee Ave  Subscriber
# 6  Clinton St & Washington Blvd             Morgan St & Lake St  Subscriber
# 7           Canal St & Adams St          Michigan Ave & Lake St  Subscriber
# 9         Canal St & Madison St              Clark St & Lake St  Subscriber
#
#   Gender  Birth Year
# 0   Male      1991.0
# 3   Male      1966.0
# 6   Male      1986.0
# 7   Male      1969.0
# 9   Male      1982.0

# %%
# only female users
female_users = df[df['Gender'] == 'Female']
female_users.head()
# Out:
#              Start Time             End Time  Trip Duration  \
# 2   2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 4   2017-01-26 15:36:07  2017-01-26 15:43:21            434
# 5   2017-06-21 09:43:54  2017-06-21 10:01:31           1057
# 12  2017-03-22 06:54:00  2017-03-22 06:59:02            302
# 21  2017-02-01 08:49:24  2017-02-01 09:06:49           1045
#
#                 Start Station                   End Station   User Type  \
# 2       Canal St & Madison St       Paulina Ave & North Ave  Subscriber
# 4      Clark St & Randolph St  Financial Pl & Congress Pkwy  Subscriber
# 5        Ogden Ave & Race Ave       Franklin St & Monroe St  Subscriber
# 12  Larrabee St & Division St             Clark St & Elm St  Subscriber
# 21       Clinton St & 18th St  Clinton St & Washington Blvd  Subscriber
#
#     Gender  Birth Year
# 2   Female      1982.0
# 4   Female      1983.0
# 5   Female      1981.0
# 12  Female      1990.0
# 21  Female      1985.0

# %%
plt.scatter(df['User Type'], df['Trip Duration'])

# %%
df.fillna(0, inplace=True)
df.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year
# 0  Subscriber    Male      1991.0
# 1    Customer       0         0.0
# 2  Subscriber  Female      1982.0
# 3  Subscriber    Male      1966.0
# ...

# %%
# sns.catplot(df['User Type'], df['Trip Duration'])

sns.catplot(x="User Type", y="Trip Duration", data=df)

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-b959c06452a1> in <module>
# ----> 1 df.dtype
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df
# Out:
#               Start Time             End Time  Trip Duration  \
# 0    2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1    2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2    2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3    2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4    2017-01-26 15:36:07  2017-01-26 15:43:21            434
# ..                   ...                  ...            ...
# 395  2017-02-06 13:34:32  2017-02-06 13:41:35            423
# 396  2017-05-22 16:44:08  2017-05-22 16:48:05            237
# 397  2017-06-09 17:03:44  2017-06-09 17:24:30           1246
# 398  2017-05-16 08:14:27  2017-05-16 08:28:24            837
# 399  2017-05-16 12:48:34  2017-05-16 12:58:17            583
#
#                     Start Station                          End Station  \
# 0       Columbus Dr & Randolph St                 Federal St & Polk St
# 1          Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# ...

# %%
sns.catplot(x="Start Station", palette="ch:.25", kind="count", data=df)

# %%
data = df.groupby("User Type")["Trip Duration"].sum()
data
# Out:
# User Type
# Customer      109689
# Subscriber    265597
# Name: Trip Duration, dtype: int64

# %%
data.plot.pie(autopct="%.1f%%");

# %%
data = df.groupby("Gender")["Start Station"].value_counts()
data.count()
# Out:
# 281

# %%
data.plot.pie(autopct="%.1f%%");

# %%
start_station = list(df['Start Station'].unique())
print(start_station)
print(type(start_station))
# Out:
# ['Columbus Dr & Randolph St', 'Kingsbury St & Erie St', 'Canal St & Madison St', 'Spaulding Ave & Armitage Ave', 'Clark St & Randolph St', 'Ogden Ave & Race Ave', 'Clinton St & Washington Blvd', 'Canal St & Adams St', 'Wentworth Ave & Archer Ave', 'State St & Kinzie St', 'Clark St & Lake St', 'Larrabee St & Division St', 'Ashland Ave & Division St', 'LaSalle St & Washington St', 'Sheffield Ave & Webster Ave', 'Orleans St & Merchandise Mart Plaza', 'Southport Ave & Irving Park Rd', 'Central St & Girard Ave', 'Kingsbury St & Kinzie St', 'State St & Pearson St', 'Clinton St & 18th St', 'Loomis St & Jackson Blvd', 'Paulina Ave & North Ave', 'Wabash Ave & 16th St', 'Adler Planetarium', 'California Ave & Milwaukee Ave', 'Sedgwick St & North Ave', 'Oakley Ave & Irving Park Rd', 'Streeter Dr & Grand Ave', 'Franklin St & Lake St', 'Clinton St & Roosevelt Rd', 'Theater on the Lake', 'Broadway & Berwyn Ave', 'Clark St & Winnemac Ave', 'Wells St & Concord Ln', 'LaSalle St & Jackson Blvd', 'Despl
# ...

# %%
number_start_station = df["Start Station"].value_counts()
start_station = list(df['Start Station'].unique())
plt.figure(figsize=(30, 20))
g = sns.countplot(y=df['Start Station'], order=start_station)
g.set_ylabel('Start Stations')
g.set_title('Distribution of Mental Health Disorders',fontdict= { 'fontsize': 24, 'fontweight':'bold'})
plt.show()

# %%
df = pd.read_csv('chicago.csv')
df.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year
# 0  Subscriber    Male      1991.0
# 1    Customer     NaN         NaN
# 2  Subscriber  Female      1982.0
# 3  Subscriber    Male      1966.0
# ...

# %%
df['Start Date'] = pd.to_datetime(df['Start Time']).dt.date
df.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year  Start Date
# 0  Subscriber    Male      1991.0  2017-05-29
# 1    Customer     NaN         NaN  2017-06-12
# 2  Subscriber  Female      1982.0  2017-02-13
# ...

# %%
df['Starting Time'] = pd.to_datetime(df['Start Time']).dt.time 
df.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year  Start Date Starting Time
# 0  Subscriber    Male      1991.0  2017-05-29      18:36:27
# 1    Customer     NaN         NaN  2017-06-12      19:00:33
# ...

# %%
df['End Date'] = pd.to_datetime(df['End Time']).dt.date
df.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year  Start Date Starting Time    End Date
# 0  Subscriber    Male      1991.0  2017-05-29      18:36:27  2017-05-29
# ...

# %%
df['Ending Time'] = pd.to_datetime(df['End Time']).dt.time 
df.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year  Start Date Starting Time    End Date  \
# 0  Subscriber    Male      1991.0  2017-05-29      18:36:27  2017-05-29
# ...

# %%
df.rename(columns={"Start Time": "Starting Timestamp", "End Time": "Ending Timestamp"}, inplace=True)
df.head()
# Out:
#     Starting Timestamp     Ending Timestamp  Trip Duration  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year  Start Date Starting Time    End Date  \
# 0  Subscriber    Male      1991.0  2017-05-29      18:36:27  2017-05-29
# ...

# %%
df.columns
# Out:
# Index(['Starting Timestamp', 'Ending Timestamp', 'Trip Duration',
#        'Start Station', 'End Station', 'User Type', 'Gender', 'Birth Year',
#        'Start Date', 'Starting Time', 'End Date', 'Ending Time'],
#       dtype='object')

# %%
columns_reordered = ['Starting Timestamp', 'Ending Timestamp', 'Start Date', 'End Date', 'Starting Time', 'Ending Time', 'Trip Duration',
       'Start Station', 'End Station', 'User Type', 'Gender', 'Birth Year']
df = df[columns_reordered]
df.head()
# Out:
#     Starting Timestamp     Ending Timestamp  Start Date    End Date  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27  2017-05-29  2017-05-29
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22  2017-06-12  2017-06-12
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10  2017-02-13  2017-02-13
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59  2017-04-24  2017-04-24
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21  2017-01-26  2017-01-26
#
#   Starting Time Ending Time  Trip Duration                 Start Station  \
# 0      18:36:27    18:49:27            780     Columbus Dr & Randolph St
# 1      19:00:33    19:24:22           1429        Kingsbury St & Erie St
# 2      17:02:02    17:20:10           1088         Canal St & Madison St
# 3      18:39:45    18:54:59            914  Spaulding Ave & Armitage Ave
# 4      15:36:07    15:43:21            434        Clark St & Randolph St
#
#                            End Station   User Type  Gender  Birth Year
# ...

# %%
df.drop(['Start Date', 'End Date'], axis=1, inplace=True)
df.head()
# Out:
# /home/bu113t/.local/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#     Starting Timestamp     Ending Timestamp Starting Time Ending Time  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27      18:36:27    18:49:27
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22      19:00:33    19:24:22
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10      17:02:02    17:20:10
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59      18:39:45    18:54:59
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21      15:36:07    15:43:21
#
#    Trip Duration                 Start Station  \
# 0            780     Columbus Dr & Randolph St
# 1           1429        Kingsbury St & Erie St
# 2           1088         Canal St & Madison St
# ...

# %%
datetime.strptime('18:49:27', '%H:%M:%S') - datetime.strptime('18:36:27', '%H:%M:%S')
# Out:
# datetime.timedelta(seconds=780)

# %%
diff = datetime.strptime('2017-05-29 18:49:27', '%Y-%m-%d %H:%M:%S') - datetime.strptime('2017-05-29 18:36:27', '%Y-%m-%d %H:%M:%S')
minutes = divmod(diff.total_seconds(), 60)
minutes
# Out:
# (13.0, 0.0)

# %%
df.head()
# Out:
#     Starting Timestamp     Ending Timestamp Starting Time Ending Time  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27      18:36:27    18:49:27
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22      19:00:33    19:24:22
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10      17:02:02    17:20:10
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59      18:39:45    18:54:59
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21      15:36:07    15:43:21
#
#    Trip Duration                 Start Station  \
# 0            780     Columbus Dr & Randolph St
# 1           1429        Kingsbury St & Erie St
# 2           1088         Canal St & Madison St
# 3            914  Spaulding Ave & Armitage Ave
# 4            434        Clark St & Randolph St
#
#                            End Station   User Type  Gender  Birth Year  \
# 0                 Federal St & Polk St  Subscriber    Male      1991.0
# 1  Orleans St & Merchandise Mart Plaza    Customer     NaN         NaN
# ...

# %%
# sns.catplot(df['User Type'], df['Trip Duration'])

sns.catplot(x="Starting Time", y="Trip Duration", data=df)
